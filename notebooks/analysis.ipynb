# %% [markdown]
# # Analysis
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import coffee data
coffee = pd.read_csv("../data/crop/coffee_output.csv")

# import weather data
weather = pd.read_csv("../data/weather/weather_data.csv")

# %%
# TODO: Merge these two dataframes together
mg_coffee = coffee[coffee["subdivision"] == "Minas Gerais"]
coffee_weather_df = pd.merge(mg_coffee, weather, on = "year")

# %%
# TODO: View the first 5 rows of your data
coffee_weather_df.head()
# Out:
#   country subdivision_x     type  60kgs_bag  year  nonbearing_trees  \
# 0  Brazil  Minas Gerais  Arabica      16.30  2006             581.0
# 1  Brazil  Minas Gerais  Arabica      23.70  2007             563.0
# 2  Brazil  Minas Gerais  Arabica      16.85  2008             679.0
# 3  Brazil  Minas Gerais  Arabica      25.55  2009             663.0
# 4  Brazil  Minas Gerais  Arabica      22.10  2010             873.0
#
#    bearing_trees  nonbear_hectares  bearing_hectares  \
# 0         5330.0             175.0            2298.0
# 1         5730.0             186.0            2245.0
# 2         5720.0             196.0            2235.0
# 3         5770.0             188.0            2223.0
# 4         5725.0             244.0            2151.0
#
#    bearing_trees_per_hectare  ...  Unnamed: 0  rain_max   temp_avg   temp_max  \
# 0                     2319.0  ...           0  6.670968  21.803087  27.190323
# ...

# %%
# TODO: Check for null values 
coffee_weather_df.isnull().sum()
# Out:
# country                         0
# subdivision_x                   0
# type                            0
# 60kgs_bag                       0
# year                            0
# nonbearing_trees                1
# bearing_trees                   1
# nonbear_hectares                1
# bearing_hectares                1
# bearing_trees_per_hectare       1
# nonbearing_trees_per_hectare    1
# Unnamed: 0                      0
# rain_max                        0
# temp_avg                        0
# temp_max                        0
# temp_min                        0
# hum_max                         0
# hum_min                         0
# wind_max                        0
# wind_avg                        0
# subdivision_y                   0
# dtype: int64

# %%
# TODO: Drop rows that contain null values
coffee_weather_df.dropna(inplace=True)

# %%
# TODO: BEGIN YOUR EDA!
# generate a scatter plot with temp_avg vs. 60kgs_bag 
sns.scatterplot(data = coffee_weather_df, x = coffee_weather_df['temp_avg'], y = coffee_weather_df['60kgs_bag'], markers = True, marker = 'o')
plt.xlabel('Temperature Average')
plt.ylabel('60kgs Bag')
plt.title('Temperature Average & 60kgs Bag')
plt.show()
print(coffee_weather_df['temp_avg'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))

# generate a scatter plot with hum_min vs. 60kgs_bag 
sns.scatterplot(data = coffee_weather_df, x = coffee_weather_df['hum_min'], y = coffee_weather_df['60kgs_bag'], markers = True, marker = 'o')
plt.xlabel('Minimum Humidity')
plt.ylabel('60kgs Bag')
plt.title('Minimum Humidity & 60kgs Bag')
plt.show()
print(coffee_weather_df['hum_min'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))

# generate a scatter plot with rain_max vs. 60kgs_bag 
sns.scatterplot(data = coffee_weather_df, x = coffee_weather_df['rain_max'], y = coffee_weather_df['60kgs_bag'], markers = True, marker = 'o')
plt.xlabel('Maximum Rain')
plt.ylabel('60kgs Bag')
plt.title('Maximum Rain & 60kgs Bag')
plt.show()
print(coffee_weather_df['rain_max'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))

# generate a scatter plot with wind_avg vs. 60kgs_bag 
sns.scatterplot(data = coffee_weather_df, x = coffee_weather_df['wind_avg'], y = coffee_weather_df['60kgs_bag'], markers = True, marker = 'o')
plt.xlabel('Average Wind Speed')
plt.ylabel('60kgs Bag')
plt.title('Average Wind Speed & 60kgs Bag')
plt.show()
print(coffee_weather_df['wind_avg'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))

# generate a scatter plot with temp_avg vs. 60kgs_bag 
sns.scatterplot(data = coffee_weather_df, x = coffee_weather_df['temp_avg'], y = coffee_weather_df['bearing_trees_per_hectare'], markers = True, marker = 'o')
plt.xlabel('Average Temperature')
plt.ylabel('Bearing Trees Per Hectare')
plt.title('Average Temperature & Bearing Trees Per Hectare')
plt.show()
print(coffee_weather_df['temp_avg'].corr(coffee_weather_df['bearing_trees_per_hectare'], method='pearson'))

# get all Correlation Coefficient of 60kgs_bag with different weather conditions
print('rain_max vs 60kgs_bag: ', coffee_weather_df['rain_max'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))
print('temp_min vs 60kgs_bag: ', coffee_weather_df['temp_min'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))
print('temp_max vs 60kgs_bag: ', coffee_weather_df['temp_max'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))
print('temp_avg vs 60kgs_bag: ', coffee_weather_df['temp_avg'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))
print('wind_avg vs 60kgs_bag: ', coffee_weather_df['wind_avg'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))
print('wind_max vs 60kgs_bag: ', coffee_weather_df['wind_max'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))
print('hum_max vs 60kgs_bag: ', coffee_weather_df['hum_max'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))
print('hum_min vs 60kgs_bag: ', coffee_weather_df['hum_min'].corr(coffee_weather_df['60kgs_bag'], method='pearson'))
# Out:
# -0.12477217306378095
# -0.5401709088326815
# -0.395810991373492
# -0.7073271023009807
# -0.4320757039885075
# rain_max vs 60kgs_bag:  -0.395810991373492
# temp_min vs 60kgs_bag:  -0.4650889503832358
# temp_max vs 60kgs_bag:  0.6663839852977869
# temp_avg vs 60kgs_bag:  -0.12477217306378095
# wind_avg vs 60kgs_bag:  -0.7073271023009807
# wind_max vs 60kgs_bag:  -0.7416515185735788
# hum_max vs 60kgs_bag:  0.267552593500615
# hum_min vs 60kgs_bag:  -0.5401709088326815

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %% [markdown]
# What is the relationship between temp_avg and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# Answer: The Correlation Coefficient between temp_avg and 60kgs_bag is around -0.1248, which indicated that the relationship are negative week related.

# %% [markdown]
# What is the relationship between minimum humidity and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# Answer: The Correlation Coefficient between minimum humidity and 60kgs bag is around -0.54017, which indicated that the relationship are negative moderate related.

# %% [markdown]
# What is the relationship between rain_max and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# Answer: The Correlation Coefficient between maximum rain and 60kgs bag is around -0.3958, which indicated that the relationship are week negative related.

# %% [markdown]
# What is the relationship between average wind speed and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# Answer: The Correlation Coefficient between average wind speed and 60kgs bag is around -0.70732, which indicated that the relationship are negative week related.

# %% [markdown]
# Perform the same bivariate analysis between the mentioned weather columns (temp_avg, hum_min, rain_max, and wind_avg) and a coffee-related column of your choice (bearing_trees, nonbearing_trees, bearing_trees_per_hectare, etc). Which directions do these relationships follow? What are the strengths of these relationships?
#
# Answer: temp_avg vs. bearing_trees_per_hectare => The Correlation Coefficient between temp_avg and bearing_trees_per_hectare is around -0.43208, which indicated that the relationship are negative moderate related.

# %% [markdown]
# Which weather factor seems to influence coffee production the most?
#
# Answer: The maximum wind will be the factor that influence the most, because the Correlation Coefficient is -0.74165, which indicated that the relationship are strong negative related.

# %% [markdown]
# Which data would you collect to continue exploring the impacts of weather and economic forces on coffee production?
#
# Answer: I think I will collect the data of rainfall frequency, which refers to how often it rains over a given period. This can be ship if the coffee plants get water regularly, which is important for them to grow well.

# %% [markdown]
# If you were preparing a report to provide coffee farmers, which weather condititions would you state are the most favorable for coffee growing (assuming any exist)?
#
# Answer: Based on the Data, maximum temperature has the strongest positive correlation with coffee measured in 60kg bags. This means that, when the maximum temperature is higher, coffee production tends to increase as well.
