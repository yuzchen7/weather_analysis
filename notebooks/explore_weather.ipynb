# %% [markdown]
# # Explore Weather
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import data
weather1 = pd.read_csv("../data/weather/weather_data1.csv")
weather2 = pd.read_csv("../data/weather/weather_data2.csv")

# %%
# TODO: concatenate your data files together and save to a new csv file ("../data/weather/weather_data.csv")
pd.concat([weather1, weather2])
# Out:
#    year  rain_max   temp_avg   temp_max   temp_min    hum_max    hum_min  \
# 0  2006  6.670968  21.803087  27.190323  18.654839  97.129032  57.806452
# 1  2007  1.866250  23.040999  27.649375  18.753125  87.837500  48.493750
# 2  2008  3.777049  20.682400  27.000000  16.216393  96.136612  51.415301
# 3  2009  3.380220  21.023802  27.769231  16.410440  96.054945  49.329670
# 4  2010  2.183516  21.444293  28.580769  16.156044  95.247253  44.648352
# 5  2011  2.601786  20.959536  27.735714  16.318132  96.060440  49.252747
# 6  2012  2.255738  21.030624  28.406011  16.003279  96.060109  46.366120
# 7  2013  3.079121  21.088660  27.976923  16.386813  96.802198  49.390110
# 8  2014  1.617582  21.163462  28.406044  15.684066  96.214286  44.824176
# 0  2015  2.876923  21.346828  28.487912  16.475275  97.450549  48.406593
# 1  2016  2.641860  21.630402  28.855233  16.705233  97.587209  47.587209
# 2  2017  2.052459  21.404627  28.433607  16.409016  97.155738  47.475410
# ...

# %%
# TODO: view first 5 rows of your data
weather.head()
# Out:
#    year  rain_max   temp_avg   temp_max   temp_min    hum_max    hum_min  \
# 0  2006  6.670968  21.803087  27.190323  18.654839  97.129032  57.806452
# 1  2007  1.866250  23.040999  27.649375  18.753125  87.837500  48.493750
# 2  2008  3.777049  20.682400  27.000000  16.216393  96.136612  51.415301
# 3  2009  3.380220  21.023802  27.769231  16.410440  96.054945  49.329670
# 4  2010  2.183516  21.444293  28.580769  16.156044  95.247253  44.648352
#
#    wind_max  wind_avg   subdivision
# 0  9.706452  2.075207  Minas Gerais
# 1  8.749375  2.069605  Minas Gerais
# 2  8.865027  1.584408  Minas Gerais
# 3  9.114286  1.611746  Minas Gerais
# 4  9.109341  1.455907  Minas Gerais

# %%
# TODO: describe your numeric columns
weather.describe()
# Out:
#               year   rain_max   temp_avg   temp_max   temp_min    hum_max  \
# count    18.000000  18.000000  18.000000  18.000000  18.000000  18.000000
# mean   2014.500000   3.175087  21.285831  28.198312  16.458525  96.502990
# std       5.338539   1.190658   0.549483   0.564714   0.891070   2.345644
# min    2006.000000   1.617582  20.682400  27.000000  15.268681  87.837500
# 25%    2010.250000   2.342250  20.975602  27.811486  16.041470  96.079483
# 50%    2014.500000   2.978022  21.126061  28.406027  16.319722  97.089241
# 75%    2018.750000   3.718815  21.434377  28.614973  16.459066  97.553044
# max    2023.000000   6.670968  23.040999  29.010989  18.753125  98.500000
#
#          hum_min   wind_max   wind_avg
# count  18.000000  18.000000  18.000000
# mean   48.528039   8.469412   1.286295
# std     3.010135   0.611327   0.399773
# min    44.648352   7.484426   0.812202
# 25%    47.154325   7.906319   0.911424
# 50%    48.450172   8.489286   1.216155
# ...

# %%
# TODO: display the null values in your dataframe
weather.isnull().sum()
# Out:
# year           0
# rain_max       0
# temp_avg       0
# temp_max       0
# temp_min       0
# hum_max        0
# hum_min        0
# wind_max       0
# wind_avg       0
# subdivision    0
# dtype: int64

# %%
# TODO: BEGIN YOUR EDA!
sns.lineplot(data = weather, x = weather['year'], y = weather['temp_avg'], markers=True, marker='o')
plt.xlabel('Years')
plt.ylabel('Average Temperature')
plt.title('Average Temperature Change Across Years')
plt.show()

sns.lineplot(data = weather, x = weather['year'], y = weather['hum_min'], markers=True, marker='o')
plt.xlabel('Years')
plt.ylabel('Minimum Humidity')
plt.title('Minimum Humidity Change Across Years')
plt.show()

sns.lineplot(data = weather, x = weather['year'], y = weather['wind_avg'], markers=True, marker='o')
plt.xlabel('Years')
plt.ylabel('Average Wind Speed')
plt.title('Average Wind Speed Change Across Years')
plt.show()

rainfall_max = weather['rain_max'].max();
weather.loc[weather['rain_max'] == rainfall_max, 'year'].item()

sns.scatterplot(data=weather, x=weather['rain_max'], y=weather['hum_max'])
plt.title('max rainfall & max humidity')
plt.xlabel('max rainfall')
plt.ylabel('max humidity')
plt.show()

r_and_h_corr_coef = weather['rain_max'].corr(weather['hum_max'], method='pearson')
print('Correlation Coefficient:', r_and_h_corr_coef)

sns.scatterplot(data=weather, x=weather['wind_avg'], y=weather['temp_avg'])
plt.title('Average Wind Speed & Average Temperature')
plt.xlabel('Average Wind Speed')
plt.ylabel('Average Temperature')
plt.show()

w_and_t_corr_coef = weather['wind_avg'].corr(weather['temp_avg'], method='pearson')
print('Correlation Coefficient:', w_and_t_corr_coef)
# Out:
# Correlation Coefficient: 0.4057821680144417
# Correlation Coefficient: 0.4765294973950924

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %% [markdown]
# How is average temperature changing across the years for Minas Gerais? Is this increasing or decreasing?
#
# Answer: Based on the line plot virtualization, the average temperature changing across the years are decreased in overall.

# %% [markdown]
# How is minimum humidity changing across the years for Minas Gerais? Is this increasing or decreasing?
#
# Answer: Based on the line plot virtualization, the minimum humidity changing across the years for Minas Gerais are decreased in overall.

# %% [markdown]
# How is average wind speed changing across the years for Minas Gerais? Is this increasing or decreasing?
#
# Answer: Based on the line plot virtualization, the average wind speed changing across the year for Minas Gerais are strongly decreased in overall.

# %% [markdown]
# Which year had the highest maximum record rainfall?
#
# Answer: The highest maximum record rainfall is in 2006.

# %% [markdown]
# What is the relationship between max rain and max humidity? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# Answer: The Correlation Coefficient between max rain and max humidity is around 0.40579, which indicated that the relationship are positive moderate related.

# %% [markdown]
# What is the relationship between average wind speed and average temperature? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# Answer: The Correlation Coefficient between max wind speed and max temperature is around 0.47653, which indicated that the relationship are positive moderate strong.
